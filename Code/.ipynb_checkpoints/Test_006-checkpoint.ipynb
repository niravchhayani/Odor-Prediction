# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import time
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as sm

from scipy import stats

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

from itertools import takewhile

# %%
# Loading metadata
metadata = np.loadtxt('../Data/HT_Sensor_metadata.dat', skiprows=1, dtype=str)

# Loading dataset
dataset = np.loadtxt('../Data/HT_Sensor_dataset.dat', skiprows=1)

# %%
# Assigning heading to each column in metadata and dataset

df_metadata = pd.DataFrame(metadata, columns = ['ID', 'Date', 'Class', 't0', 'dt']) 
df_dataset = pd.DataFrame(dataset, columns = ['ID', 'Time', 'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'Temp', 'Humidity'])

# %%
# Assigning each class a number

df_metadata.loc[df_metadata['Class'] == 'wine', 'Class'] = 0
df_metadata.loc[df_metadata['Class'] == 'banana', 'Class'] = 1
df_metadata.loc[df_metadata['Class'] == 'background', 'Class'] = 2

# %%
# Merging Metadata and Dataset to create full data using 'ID'

df_metadata.ID = df_metadata.ID.astype(int)
df_dataset.ID = df_dataset.ID.astype(int)

df_fulldata = pd.merge(df_metadata, df_dataset, on='ID')
print(df_fulldata.head())
print(df_fulldata.tail())
# Out:
#    ID      Date Class     t0    dt      Time       R1       R2       R3  \
# 0   0  07-04-15     1  13.49  1.64 -0.999750  12.8621  10.3683  10.4383
# 1   0  07-04-15     1  13.49  1.64 -0.999472  12.8617  10.3682  10.4375
# 2   0  07-04-15     1  13.49  1.64 -0.999194  12.8607  10.3686  10.4370
# 3   0  07-04-15     1  13.49  1.64 -0.998916  12.8602  10.3686  10.4370
# 4   0  07-04-15     1  13.49  1.64 -0.998627  12.8595  10.3688  10.4374
#
#         R4       R5       R6       R7       R8     Temp  Humidity
# 0  11.6699  13.4931  13.3423  8.04169  8.73901  26.2257   59.0528
# 1  11.6697  13.4927  13.3412  8.04133  8.73908  26.2308   59.0299
# 2  11.6696  13.4924  13.3405  8.04101  8.73915  26.2365   59.0093
# 3  11.6697  13.4921  13.3398  8.04086  8.73936  26.2416   58.9905
# 4  11.6699  13.4919  13.3390  8.04087  8.73986  26.2462   58.9736
#         ID      Date Class     t0    dt      Time       R1       R2       R3  \
# 928986  99  09-17-15     2  11.93  0.68  1.675182  12.6224  10.5805  10.7432
# 928987  99  09-17-15     2  11.93  0.68  1.675460  12.6236  10.5796  10.7436
# 928988  99  09-17-15     2  11.93  0.68  1.675738  12.6244  10.5795  10.7437
# 928989  99  09-17-15     2  11.93  0.68  1.676016  12.6243  10.5797  10.7440
# 928990  99  09-17-15     2  11.93  0.68  1.676304  12.6248  10.5791  10.7440
#
#              R4       R5       R6       R7       R8     Temp  Humidity
# 928986  12.1775  12.6498  17.2926  6.20449  7.05966  27.7282   54.1532
# 928987  12.1780  12.6511  17.2918  6.20444  7.05980  27.7312   54.1423
# 928988  12.1782  12.6524  17.2907  6.20451  7.05967  27.7339   54.1324
# 928989  12.1784  12.6532  17.2904  6.20468  7.05969  27.7364   54.1235
# 928990  12.1784  12.6539  17.2895  6.20461  7.05944  27.7385   54.1154

# %%
# Defining an equation to find the index of of the time when induction started

def fnd_zero(l, b): return len([x for x in takewhile(lambda x: x[1] <= b, enumerate(l))])

# %%
pre_cut = 50
#post_cut = 8000
int_data = lambda df, pre_cut, key: df[key - pre_cut : -1]

NewDf_fulldata = pd.DataFrame()
for _, temp_df in df_fulldata.groupby('ID'):
    zero_loc = fnd_zero(temp_df.Time,0.0)
    #print(temp_df.shape)
    NewTemp_df = int_data(temp_df, pre_cut, zero_loc)
    #print(NewTemp_df.shape)
    frames = [NewDf_fulldata, NewTemp_df]
    NewDf_fulldata = pd.concat(frames)
NewDf_fulldata.head()

NewDf_fulldata.shape
newDf_data = NewDf_fulldata.iloc[:,1:]
newDf_class = NewDf_fulldata.iloc[:,1]

NewClass_Val = newDf_class.values
NewData_Val = newDf_data.values

Newx_train, Newx_test, Newy_train, Newy_test = train_test_split(NewData_Val, NewClass_Val, test_size = 0.2)

# %%
# Creating proper format of data as well as removing unnecessary columns.

df_fulldata.Class = df_fulldata.Class.astype(int)
df_fulldata.drop(['Date', 't0', 'dt'],axis = 1, inplace=True)

# %%
df_fulldata.head()
# Out:
#    ID  Class      Time       R1       R2       R3       R4       R5       R6  \
# 0   0      1 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1   0      1 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2   0      1 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3   0      1 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4   0      1 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
#
#         R7       R8     Temp  Humidity
# 0  8.04169  8.73901  26.2257   59.0528
# 1  8.04133  8.73908  26.2308   59.0299
# 2  8.04101  8.73915  26.2365   59.0093
# 3  8.04086  8.73936  26.2416   58.9905
# 4  8.04087  8.73986  26.2462   58.9736

# %%
df_fulldata = NewDf_fulldata

# %%
df_fulldata.head()
# Out:
#       ID      Date Class     t0    dt      Time       R1       R2       R3  \
# 3379   0  07-04-15     1  13.49  1.64 -0.013982  12.8566  10.4130  10.5095
# 3380   0  07-04-15     1  13.49  1.64 -0.013693  12.8561  10.4124  10.5098
# 3381   0  07-04-15     1  13.49  1.64 -0.013415  12.8558  10.4123  10.5102
# 3382   0  07-04-15     1  13.49  1.64 -0.013137  12.8553  10.4117  10.5104
# 3383   0  07-04-15     1  13.49  1.64 -0.012859  12.8549  10.4113  10.5103
#
#            R4       R5       R6       R7       R8     Temp  Humidity
# 3379  11.7302  13.5615  13.3528  8.31326  9.05181  26.3780   59.1128
# 3380  11.7300  13.5615  13.3524  8.31335  9.05193  26.3773   59.1212
# 3381  11.7303  13.5621  13.3520  8.31357  9.05187  26.3766   59.1272
# 3382  11.7302  13.5622  13.3517  8.31333  9.05151  26.3759   59.1326
# 3383  11.7298  13.5621  13.3514  8.31311  9.05134  26.3754   59.1375

# %%
# Creating proper format of data as well as removing unnecessary columns.

df_fulldata.Class = df_fulldata.Class.astype(int)
df_fulldata.drop(['Date', 't0', 'dt'],axis = 1, inplace=True)

# %%
corr = df_fulldata.corr()

# %%
sns.heatmap(corr)

# %%
corr
# Out:
#                 ID     Class      Time        R1        R2        R3  \
# ID        1.000000  0.651208 -0.081149  0.084866  0.136192  0.244299
# Class     0.651208  1.000000 -0.118020  0.293697  0.441429  0.463104
# Time     -0.081149 -0.118020  1.000000  0.138809  0.129991  0.112709
# R1        0.084866  0.293697  0.138809  1.000000  0.821238  0.816883
# R2        0.136192  0.441429  0.129991  0.821238  1.000000  0.862462
# R3        0.244299  0.463104  0.112709  0.816883  0.862462  1.000000
# R4        0.183640  0.461079  0.112413  0.800612  0.952954  0.913993
# R5       -0.048841 -0.083846 -0.047534  0.015708 -0.006034  0.013329
# R6        0.275302  0.021421  0.193796  0.198890  0.209597  0.267954
# R7        0.131585  0.203121  0.007623  0.238354  0.231489  0.291627
# R8        0.062069  0.143055 -0.017386  0.188970  0.188677  0.233872
# Temp      0.230804  0.160513 -0.127051  0.016008  0.008641  0.088143
# Humidity -0.030870 -0.058577 -0.023912 -0.087302 -0.065509 -0.046631
#
#                 R4        R5        R6        R7        R8      Temp  Humidity
# ID        0.183640 -0.048841  0.275302  0.131585  0.062069  0.230804 -0.030870
# Class     0.461079 -0.083846  0.021421  0.203121  0.143055  0.160513 -0.058577
# Time      0.112413 -0.047534  0.193796  0.007623 -0.017386 -0.127051 -0.023912
# R1        0.800612  0.015708  0.198890  0.238354  0.188970  0.016008 -0.087302
# R2        0.952954 -0.006034  0.209597  0.231489  0.188677  0.008641 -0.065509
# R3        0.913993  0.013329  0.267954  0.291627  0.233872  0.088143 -0.046631
# R4        1.000000 -0.008766  0.238617  0.256503  0.203293  0.039627 -0.085693
# R5       -0.008766  1.000000  0.121804  0.202196  0.409045 -0.057834  0.010167
# R6        0.238617  0.121804  1.000000  0.256302  0.274946 -0.087908  0.044978
# R7        0.256503  0.202196  0.256302  1.000000  0.795329  0.030904  0.010099
# R8        0.203293  0.409045  0.274946  0.795329  1.000000  0.019724  0.059991
# Temp      0.039627 -0.057834 -0.087908  0.030904  0.019724  1.000000  0.162023
# Humidity -0.085693  0.010167  0.044978  0.010099  0.059991  0.162023  1.000000

# %%
label_encoder = LabelEncoder()
df_fulldata.iloc[:,0] = label_encoder.fit_transform(df_fulldata.iloc[:,0]).astype('float64')

cols = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.8:
            if cols[j]:
                cols[j] = False
sel_cols = df_fulldata.columns[cols]
df_fulldata = df_fulldata[sel_cols]

sel_cols = sel_cols[1:].values

def backwardElimination(x, Y, sl, columns):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(Y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
                    columns = np.delete(columns, j)
                    
    regressor_OLS.summary()
    return x, columns

# %%
SL = 0.05
data_modeled, sel_cols = backwardElimination(df_fulldata.iloc[:,1:].values, df_fulldata.iloc[:,0].values, SL, sel_cols)

# %%
result = pd.DataFrame()
result['Class'] = df_fulldata.iloc[:,0]

data = pd.DataFrame(data = data_modeled, columns = sel_cols)

# %%
data.head()
# Out:
#    Class      Time       R1       R5       R6       R7       R8     Temp  \
# 0    1.0 -0.013982  12.8566  13.5615  13.3528  8.31326  9.05181  26.3780
# 1    1.0 -0.013693  12.8561  13.5615  13.3524  8.31335  9.05193  26.3773
# 2    1.0 -0.013415  12.8558  13.5621  13.3520  8.31357  9.05187  26.3766
# 3    1.0 -0.013137  12.8553  13.5622  13.3517  8.31333  9.05151  26.3759
# 4    1.0 -0.012859  12.8549  13.5621  13.3514  8.31311  9.05134  26.3754
#
#    Humidity
# 0   59.1128
# 1   59.1212
# 2   59.1272
# 3   59.1326
# 4   59.1375

# %%
x_train_fea, x_test_fea, y_train_fea, y_test_fea = train_test_split(data.values, result.values, test_size = 0.2)

# %%
start = time.time()
svc=SVC() # The default kernel used by SVC is the gaussian kernel
svc.fit(x_train_fea, y_train_fea)
end = time.time()
print(end - start)
# Out:
# /home/nrvptl/.local/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/nrvptl/.local/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 561.904611825943

# %%
start = time.time()
prediction = svc.predict(x_test_fea)
end = time.time()
print(end - start)
# Out:
# 411.4345316886902

# %%
start = time.time()
cm = confusion_matrix(y_test_fea, prediction)
sum = 0
for i in range(cm.shape[0]):
    sum += cm[i][i]
    
accuracy = sum/x_test_fea.shape[0]
print(accuracy)
end = time.time()
print(end - start)
# Out:
# 0.9997548273646478
# 0.1361682415008545

# %%
df_fulldata.head()
# Out:
#        ID  Class      Time       R1       R5       R6       R7       R8  \
# 3379  0.0      1 -0.013982  12.8566  13.5615  13.3528  8.31326  9.05181
# 3380  0.0      1 -0.013693  12.8561  13.5615  13.3524  8.31335  9.05193
# 3381  0.0      1 -0.013415  12.8558  13.5621  13.3520  8.31357  9.05187
# 3382  0.0      1 -0.013137  12.8553  13.5622  13.3517  8.31333  9.05151
# 3383  0.0      1 -0.012859  12.8549  13.5621  13.3514  8.31311  9.05134
#
#          Temp  Humidity
# 3379  26.3780   59.1128
# 3380  26.3773   59.1212
# 3381  26.3766   59.1272
# 3382  26.3759   59.1326
# 3383  26.3754   59.1375

# %%
pre_cut = 1000
post_cut = 5000
int_data = lambda df, pre_cut, post_cut, key: df[key - pre_cut : key + post_cut]

# %%
NewDf_fulldata = pd.DataFrame()
for _, temp_df in df_fulldata.groupby('ID'):
    zero_loc = fnd_zero(temp_df.Time,0.0)
    #print(temp_df.shape)
    NewTemp_df = int_data(temp_df, pre_cut, post_cut, zero_loc)
    #print(NewTemp_df.shape)
    frames = [NewDf_fulldata, NewTemp_df]
    NewDf_fulldata = pd.concat(frames)
NewDf_fulldata.head()
# Out:
#         ID  Class      Time       R1       R5       R6       R7       R8  \
# 20778  1.0      0  1.231266  13.2909  13.6169  16.0362  5.94684  6.71911
# 20779  1.0      0  1.231544  13.2914  13.6184  16.0370  5.94757  6.71985
# 20780  1.0      0  1.231822  13.2918  13.6197  16.0376  5.94824  6.72051
# 20781  1.0      0  1.232100  13.2927  13.6209  16.0385  5.94884  6.72112
# 20782  1.0      0  1.232378  13.2930  13.6220  16.0393  5.94950  6.72179
#
#           Temp  Humidity
# 20778  25.8863   55.3682
# 20779  25.8848   55.3731
# 20780  25.8834   55.3775
# 20781  25.8821   55.3798
# 20782  25.8809   55.3805

# %%
NewDf_fulldata.shape
newDf_data = NewDf_fulldata.iloc[:,1:]
newDf_class = NewDf_fulldata.iloc[:,1]

# %%
print(newDf_class.head())
# Out:
# 20778    0
# 20779    0
# 20780    0
# 20781    0
# 20782    0
# Name: Class, dtype: int64

# %%
NewClass_Val = newDf_class.values
NewData_Val = newDf_data.values

Newx_train, Newx_test, Newy_train, Newy_test = train_test_split(NewData_Val, NewClass_Val, test_size = 0.2)

# %%
start = time.time()
svc=SVC() # The default kernel used by SVC is the gaussian kernel
svc.fit(Newx_train, Newy_train)
end = time.time()
print(end - start)
# Out:
# /home/nrvptl/.local/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 1.937633752822876

# %%
start = time.time()
prediction = svc.predict(Newx_test)
end = time.time()
print(end - start)
# Out:
# 0.24881219863891602

# %%
start = time.time()
cm = confusion_matrix(Newy_test, prediction)
sum = 0
for i in range(cm.shape[0]):
    sum += cm[i][i]
    
accuracy = sum/Newx_test.shape[0]
print(accuracy)
end = time.time()
print(end - start)
# Out:
# 1.0
# 0.009294271469116211

# %%
#### 2. Test - 2:
2000 samples before induction to 8000 samples after the induction started

Model : SVC

pre_cut = 2000
post_cut = 8000
int_data = lambda df, pre_cut, post_cut, key: df[key - pre_cut : key + post_cut]

NewDf_fulldata = pd.DataFrame()
for _, temp_df in df_fulldata.groupby('ID'):
    zero_loc = fnd_zero(temp_df.Time,0.0)
    #print(temp_df.shape)
    NewTemp_df = int_data(temp_df, pre_cut, post_cut, zero_loc)
    #print(NewTemp_df.shape)
    frames = [NewDf_fulldata, NewTemp_df]
    NewDf_fulldata = pd.concat(frames)
NewDf_fulldata.head()

NewDf_fulldata.shape
newDf_data = NewDf_fulldata.iloc[:,1:]
newDf_class = NewDf_fulldata.iloc[:,1]

NewClass_Val = newDf_class.values
NewData_Val = newDf_data.values

Newx_train, Newx_test, Newy_train, Newy_test = train_test_split(NewData_Val, NewClass_Val, test_size = 0.2)

start = time.time()
svc=SVC() # The default kernel used by SVC is the gaussian kernel
svc.fit(Newx_train, Newy_train)
end = time.time()
print(end - start)

start = time.time()
prediction = svc.predict(Newx_test)
end = time.time()
print(end - start)

start = time.time()
cm = confusion_matrix(Newy_test, prediction)
sum = 0
for i in range(cm.shape[0]):
    sum += cm[i][i]
    
accuracy = sum/Newx_test.shape[0]
print(accuracy)
end = time.time()
print(end - start)
